# %% [markdown]
# <a href="https://colab.research.google.com/github/liangjieyu123/CropIntensity/blob/main/%E8%AF%BB%E5%8F%96%E4%BA%91%E7%9B%98%E4%B8%AD%E7%9A%84%E6%95%B0%E6%8D%AE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/MyDrive/model/pytorch-lightning-unet/train_img"
os.chdir(path)
os.listdir(path)

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

img = Image.open("BJ2000520171218RGB_2_img.png")
print(img.mode)
plt.figure("img")
plt.imshow(img)
plt.show()
# Out:
# RGB
